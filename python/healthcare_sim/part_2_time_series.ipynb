# %% [markdown]
# ## Part 2. Time Series analysis of Master data file
#
# In part 2 we want to explore our data and its trends over time. Hopefully we will uncover further features and behaviours of our sample.

# %%
import pandas as pd

df_master = pd.read_csv('master_file.csv', parse_dates=[0], infer_datetime_format=True)
df_master.head()
# Out:
#         Date    Type        Patient     Doctor    Town
# 0 2020-01-02    Home  patient_17268  doctor_47  town_1
# 1 2020-01-02  Clinic  patient_19126  doctor_47  town_1
# 2 2020-01-02    Home  patient_19521  doctor_47  town_1
# 3 2020-01-02  Clinic   patient_3399  doctor_47  town_1
# 4 2020-01-02  Clinic  patient_18881  doctor_47  town_1

# %% [markdown]
# Let's do a simple plot of the behaviour over the trail period. We will need to group the dates together to aggregate the other fields.

# %%
df_grouped_days = df_master.groupby(by='Date', as_index=False).count()
df_grouped_days.head()
# Out:
#         Date  Type  Patient  Doctor  Town
# 0 2020-01-02   494      494     494   494
# 1 2020-01-03   489      489     489   489
# 2 2020-01-04   500      500     500   500
# 3 2020-01-05   500      500     500   500
# 4 2020-01-06   494      494     494   494

# %% [markdown]
# Grouping the dates by counts shows us the total number of patient/doctor interactions in a given day. The 'Patient' column is the most intuitive column here as we can interpret it as "The total number of patients seen on this date".
#
# *As an aside,  the values in the other columns are an exact match but are less intuitive to describe i.e. "The total number of visit types registered on a given date". This is the same as the number of "patients seen", but harder to convey to the end audience. This should be a primary consideration in data analysis/visualisation.*

# %%
import plotly.express as px

fig = px.line(df_grouped_days, x='Date', y='Patient')
fig.update_layout(yaxis_title='No. of Patients Seen', title='Total # of patients seen per day')

fig.show()

# %% [markdown]
# This is an interesting profile. The number of patients seen each day is hovering just under 500 everyday. However, every ~2 weeks or so theres a sudden jump in the count, almost reaching 750 in a single day, a single day increase of 50%!
#
# Perhaps there's a "Healthcare Drive" every two weeks that we are unaware of. To determine if this might be the case, we should restructure our Date column to include the days of the week. A fortnightly drive should be on the same day of the week for consistency and planning.

# %% [markdown]
# To determine this, we will filter our grouped data for days which have more than 700 visits, and then determine the day of the week that they occured.

# %%
df_super_day = df_grouped_days.loc[df_grouped_days['Patient']>700]

df_super_day['DOW'] = df_super_day.Date.dt.day_name()

df_super_day.head(10)
# Out:
# <ipython-input-51-5468f2595180>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Date  Type  Patient  Doctor  Town        DOW
# 14  2020-01-16   739      739     739   739   Thursday
# 29  2020-01-31   738      738     738   738     Friday
# 44  2020-02-15   743      743     743   743   Saturday
# 59  2020-03-01   740      740     740   740     Sunday
# 74  2020-03-16   735      735     735   735     Monday
# 89  2020-03-31   740      740     740   740    Tuesday
# 104 2020-04-15   737      737     737   737  Wednesday
# 119 2020-04-30   735      735     735   735   Thursday
# 134 2020-05-15   732      732     732   732     Friday
# 149 2020-05-30   731      731     731   731   Saturday

# %% [markdown]
# Now this is more suprising. The frequency where these "super days" are occurring is every 15 days, incrementing to the next day of the week.
# This is highly bizzare if there was an event or drive associated with these numbers, and now causes the numbers themselves to be suspect.
#
# We should investgate are these spikes caused by all towns equally, or a few outliers.

# %% [markdown]
# Now let's focus on the 'super days'.

# %%
df_master_super = df_master[df_master['Date'].isin(df_super_day['Date'])]

# %%
fig = px.histogram(df_master_super, x='Town',
                    title='Cumulative "Super Day" visits by Town')

fig.show()

# %% [markdown]
# This is a highly striking result. It is very clear that Town_43 is resonsible for the overwhelming majority of the numbers seen in the "Super Day" spikes. For the total time period, Town_43 represents an *order of magnitude* more interactions than every other town.
#
# This type of distcrepancy is highly suspect and warrants our client's attention.
#
# Finally, we will reprocess the chart above, but control by Doctor. This will show us if it is one or more doctor producing this irregular result.

# %%
fig = px.histogram(df_master_super, x='Town',
                    title='Cumulative "Super Day" visits by Town',
                    color='Doctor')

fig.show()

# %% [markdown]
# Coloring the histogram by Doctor, we can see two features:
# 1. Town_43 and its suspicious numbers are evenly split between both doctors working in that area. Both will need further investigation by the client.
#
# 2. As previously observed in part 1., towns with two doctors achieve twice as much as those with one. Whether this is view as a total count, on a specific day, or a seemingly special event such as the "Super Days" (now proven false).
#
# Additionally, we see the *low-performing* towns highlighted in part 1. are also shown to be low performing in this analysis, which helps improve our confidence in our first analysis.

# %% [markdown]
# ## Conclusion: The lagging and the exceptional
#
# Our two part analysis has uncovered the extremes of the client's project:
# * The weakest towns and associated doctors: Town_5, 22 and 23.
# * The suspiciously strong, and likely misleading towns and doctors: Town_43
# * A town that is most likely rural, based on 100% home visits: Town_6
#
# Determining these features of the data allows us to provide real insight to the client and suggest to them where they should focus their attention.
# They might give Town_6 a car due to its rural patient list. They might provide additional resources or training to the lagging towns to help them match their colleagues' numbers.
# They might keep a closer eye on Town_43 and ask them to provide further details of their visits to justify such irregular visit spikes.
#
# As the analyst of the data we can only show the result. What the client does with this new information is entirely up to them.
